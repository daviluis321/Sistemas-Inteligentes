# %%
import graphlab
dicionario = graphlab.SFrame('train.csv')
# Out:
# Finished parsing file /home/douglas/Sistemas-Inteligentes/TrabalhoFinal/Naara/train.csv
# Parsing completed. Parsed 100 lines in 1.02133 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,int,int,str,int,str,int,str,int,int,int,int,str,int,str,int,int,int,int,int,int,int,str,int,str,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,str,int,str,int,str,int,str,int,int,int,int,str,str,str,str,float,float,float,float,str,str,str,str,int,str,str,str,str,int,int,int,int,int,int,int,str,str,str,str,int,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,int,int,int,int,int,int,int,int,int,int,int,int,int,str,str,str,str,str,str,str,str,str]
# ...

# %%
dicionario
# Out:
# Columns:
# 	X1	int
# 	NU_INSCRICAO	str
# 	NU_ANO	int
# 	CO_MUNICIPIO_RESIDENCIA	int
# 	NO_MUNICIPIO_RESIDENCIA	str
# 	CO_UF_RESIDENCIA	int
# 	SG_UF_RESIDENCIA	str
# 	NU_IDADE	int
# 	TP_SEXO	str
# 	TP_ESTADO_CIVIL	int
# 	TP_COR_RACA	int
# 	TP_NACIONALIDADE	int
# 	CO_MUNICIPIO_NASCIMENTO	int
# 	NO_MUNICIPIO_NASCIMENTO	str
# 	CO_UF_NASCIMENTO	int
# 	SG_UF_NASCIMENTO	str
# 	TP_ST_CONCLUSAO	int
# 	TP_ANO_CONCLUIU	int
# 	TP_ESCOLA	int
# 	TP_ENSINO	int
# 	IN_TREINEIRO	int
# 	CO_ESCOLA	int
# 	CO_MUNICIPIO_ESC	int
# 	NO_MUNICIPIO_ESC	str
# 	CO_UF_ESC	int
# 	SG_UF_ESC	str
# 	TP_DEPENDENCIA_ADM_ESC	int
# 	TP_LOCALIZACAO_ESC	int
# 	TP_SIT_FUNC_ESC	int
# 	IN_BAIXA_VISAO	int
# 	IN_CEGUEIRA	int
# 	IN_SURDEZ	int
# 	IN_DEFICIENCIA_AUDITIVA	int
# 	IN_SURDO_CEGUEIRA	int
# 	IN_DEFICIENCIA_FISICA	int
# 	IN_DEFICIENCIA_MENTAL	int
# 	IN_DEFICIT_ATENCAO	int
# 	IN_DISLEXIA	int
# 	IN_DISCALCULIA	int
# 	IN_AUTISMO	int
# 	IN_VISAO_MONOCULAR	int
# 	IN_OUTRA_DEF	int
# 	IN_SABATISTA	int
# 	IN_GESTANTE	int
# ...

# %%
media = (dicionario['NU_NOTA_CN']+dicionario['NU_NOTA_CH']+dicionario['NU_NOTA_LC']+dicionario['NU_NOTA_MT'])/1+2+3+4)
# Out:
# [2427.5, 2235.0, 1897.0, 1743.3000000000002, None, 2197.7999999999997, None, 2215.8, 2239.1, 1865.6000000000001, 1863.4, None, 2102.5, 2008.3999999999999, 1982.8999999999999, 1878.1, 2189.3, None, 2060.5, 2061.9, 2127.5, 2145.8, 2823.2, 1786.2, 1805.1, None, 2016.3, None, 1858.9, 2287.2, 1924.4, 2068.4, 1814.6, 1776.5, 1860.9, 2441.2, 1606.8000000000002, 2352.0, 2069.9, 2124.6, 1816.5, 1998.2, 2907.7, 2717.3, 2105.1, 1996.6999999999998, 2147.6, 1735.0, 2087.0, 1896.2, None, None, 1852.8, 1790.8, 2216.9, None, 1868.6000000000001, None, None, None, 1716.2, 2016.3999999999999, 1864.9, 1603.1, 1592.8999999999999, 2041.6000000000001, 1760.5, 1988.4999999999998, 1740.7, None, 2300.7, 2165.6000000000004, 2034.6, 1956.0, None, 2085.4, None, 2184.8, 1688.8000000000002, 1662.1999999999998, 2739.6000000000004, 2968.0999999999995, 2036.3, 2877.1, 2597.8999999999996, None, None, 2038.9, 1799.7, 1944.0, None, None, 1912.0, 2311.6, 1828.4, 2575.8999999999996, 1891.7, 2043.6999999999998, None, 2066.
# ...

# %%
m = []
m.append(media)
m.append(1)
sa = graphlab.SArray(m)

# %%
sa
